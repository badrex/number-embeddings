# %%
import papermill as pm

# %%
model_id = "sentence-transformers/all-MiniLM-L12-v2" #"mixedbread-ai/mxbai-embed-large-v1"

pm.execute_notebook(
   "embedding_RDM.ipynb",
   "embedding_RDM_2.ipynb",
   parameters = dict(emb_model_id=model_id, multimodal=False)
)

# %%
# Out:
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-07-31T13:53:25.171265',
#      'end_time': '2024-07-31T13:53:25.993100',
#      'duration': 0.821835,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-07-31T13:53:25.175326Z',
#      'iopub.execute_input': '2024-07-31T13:53:25.175678Z',
#      'iopub.status.idle': '2024-07-31T13:53:25.991723Z',
#      'shell.execute_reply': '2024-07-31T13:53:25.991377Z'}},
#    'outputs': [],
#    'source': 'import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom collections import defaultdict, Counter\nfrom typing import List, Dict, Any, Tuple',
#    'id': '9bd07aaf'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
# ...

# %%
model_id = "sentence-transformers/all-MiniLM-L6-v2"

pm.execute_notebook(
   "embedding_RDM.ipynb",
   "embedding_RDM_3.ipynb",
   parameters = dict(emb_model_id=model_id, multimodal=False)
)
# Out:
# Executing:   0%|          | 0/32 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-07-31T14:06:24.911756',
#      'end_time': '2024-07-31T14:06:26.099663',
#      'duration': 1.187907,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-07-31T14:06:24.919808Z',
#      'iopub.execute_input': '2024-07-31T14:06:24.920181Z',
#      'shell.execute_reply': '2024-07-31T14:06:26.096133Z',
#      'iopub.status.idle': '2024-07-31T14:06:26.097223Z'}},
#    'outputs': [],
#    'source': 'import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nfrom collections import defaultdict, Counter\nfrom typing import List, Dict, Any, Tuple',
#    'id': '1a5756af'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
# ...
